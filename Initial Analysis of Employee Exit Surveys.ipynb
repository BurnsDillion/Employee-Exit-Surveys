# %% [markdown]
# # Cleaning and Analyzing Employee Exit Surveys
# We will be analyzing exit surveys from employees of the Department of Education, Training and Employment ([DETE](https://data.gov.au/dataset/ds-qld-fe96ff30-d157-4a81-851d-215f2a0fe26d/details?q=exit%20survey)) and the Technical and Further Education ([TAFE](https://data.gov.au/dataset/ds-qld-89970a3b-182b-41ea-aea2-6f9f17b5907e/details?q=exit%20survey)) insitute.
# You can find the sourcing for the data by clicking on the acronym hyperlinks of the respective organization. We will work to try and answer the following questions:
# * Are employees who only worked for insitutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been there longer?
# * Are younger employees resigning due to some kind of dissatisfaction? What about older employees?

# %% [markdown]
# ### DETE Survey Column Definitions (inferred)
# * **ID**: An id used to identify the participant of the survey
# * **SeparationType**: The reason why the person's employment ended
# * **Cease Date**: The year or month the person's employment ended
# * **DETE Start Date**: The year the person began employment with the DETE

# %% [markdown]
# ### TAFE Survey Column Definitions (inferred)
# * **Record ID**: An id used to identify the participant of the survey
# * **Reason for ceasing employment**: The reason why the person's employment ended
# * **LengthofServiceOverall. Overall Length of Service at Institute (in years)**: The length of the person's employment (in years)

# %%
# Libraries and reading-in
import pandas as pd
import numpy as np

dete_survey = pd.read_csv('dete_survey.csv')
tafe_survey = pd.read_csv('tafe_survey.csv')

# %% [markdown]
# ## Data Exploration - DETE

# %%
dete_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   822 non-null    int64
#  1   SeparationType                       822 non-null    object
#  2   Cease Date                           822 non-null    object
#  3   DETE Start Date                      822 non-null    object
#  4   Role Start Date                      822 non-null    object
#  5   Position                             817 non-null    object
#  6   Classification                       455 non-null    object
#  7   Region                               822 non-null    object
#  8   Business Unit                        126 non-null    object
#  9   Employment Status                    817 non-null    object
#  10  Career move to public sector         822 non-null    bool
# ...

# %%
dete_survey.describe()
# Out:
#                ID
# count  822.000000
# mean   411.693431
# std    237.705820
# min      1.000000
# 25%    206.250000
# 50%    411.500000
# 75%    616.750000
# max    823.000000

# %%
pd.set_option('display.max_columns', None)

dete_survey.head()
# Out:
#     ID                        SeparationType Cease Date DETE Start Date  \
# 0    1                 Ill Health Retirement    08/2012            1984
# 1    2      Voluntary Early Retirement (VER)    08/2012      Not Stated
# 2    3      Voluntary Early Retirement (VER)    05/2012            2011
# 3    4             Resignation-Other reasons    05/2012            2005
# 4    5                        Age Retirement    05/2012            1970
# 5    6             Resignation-Other reasons    05/2012            1994
# 6    7                        Age Retirement    05/2012            1972
# 7    8                        Age Retirement    05/2012            1988
# 8    9             Resignation-Other reasons    07/2012            2009
# 9   10            Resignation-Other employer       2012            1997
# 10  11                        Age Retirement       2012            1999
# 11  12  Resignation-Move overseas/interstate       2012            2009
# ...

# %%
dete_survey['Work location'].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Work location, dtype: bool

# %%
dete_survey.isnull().sum()
# Out:
# ID                                       0
# SeparationType                           0
# Cease Date                               0
# DETE Start Date                          0
# Role Start Date                          0
# Position                                 5
# Classification                         367
# Region                                   0
# Business Unit                          696
# Employment Status                        5
# Career move to public sector             0
# Career move to private sector            0
# Interpersonal conflicts                  0
# Job dissatisfaction                      0
# Dissatisfaction with the department      0
# Physical work environment                0
# Lack of recognition                      0
# Lack of job security                     0
# Work location                            0
# Employment conditions                    0
# Maternity/family                         0
# Relocation                               0
# ...

# %%
dete_survey[dete_survey == 'Not Stated'].count()
# Out:
# ID                                       0
# SeparationType                           0
# Cease Date                              34
# DETE Start Date                         73
# Role Start Date                         98
# Position                                 0
# Classification                           0
# Region                                 105
# Business Unit                            0
# Employment Status                        0
# Career move to public sector             0
# Career move to private sector            0
# Interpersonal conflicts                  0
# Job dissatisfaction                      0
# Dissatisfaction with the department      0
# Physical work environment                0
# Lack of recognition                      0
# Lack of job security                     0
# Work location                            0
# Employment conditions                    0
# Maternity/family                         0
# Relocation                               0
# ...

# %%
dete_survey['Business Unit'].value_counts()  # Going to infer that 'Business Unit' means the department they are in
# Out:
# Education Queensland                          54
# Information and Technologies                  26
# Training and Tertiary Education Queensland    12
# Other                                         11
# Human Resources                                6
# Corporate Strategy and Peformance              5
# Early Childhood Education and Care             3
# Infrastructure                                 2
# Policy, Research, Legislation                  2
# Calliope State School                          1
# Pacific Pines SHS                              1
# Finance                                        1
# Indigenous Education and Training Futures      1
# Corporate Procurement                          1
# Name: Business Unit, dtype: int64

# %%
dete_survey['Classification'].value_counts() # I am not sure what this column means
# Out:
# Primary              161
# Secondary            124
# A01-A04               66
# AO5-AO7               46
# Special Education     33
# AO8 and Above         14
# PO1-PO4                8
# Middle                 3
# Name: Classification, dtype: int64

# %%
dete_survey['SeparationType'].value_counts()
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: SeparationType, dtype: int64

# %%
dete_survey.shape
# Out:
# (822, 56)

# %% [markdown]
# ### DETE Observations
# * 56 Columns is a large amount of data to work with, might consider weeding some of them down they may not answer my question.
# * The last 5 columns (Aboriginal, Torres Strait, South Sea, Disability, NESB) are missing almost all of the data, most likely will drop them.
# * The 'Business Unit' column is also missing most of it's data, although I think if we could fill in this data it could be helpful to answer the listed questions.
# * I am not sure what the 'Classification' column is for, it's also missing about half of it's data so may remove.
# * Several columns use 'Not Stated' instead of NaN for missing values, these will have to be changed.

# %%
tafe_survey.shape
# Out:
# (702, 72)

# %%
tafe_survey.head()
# Out:
#       Record ID                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  CESSATION YEAR Reason for ceasing employment  \
# 0  Non-Delivery (corporate)          2010.0              Contract Expired
# 1  Non-Delivery (corporate)          2010.0                    Retirement
# 2       Delivery (teaching)          2010.0                    Retirement
# 3  Non-Delivery (corporate)          2010.0                   Resignation
# 4       Delivery (teaching)          2010.0                   Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# ...

# %%
tafe_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 72 columns):
#  #   Column                                                                                                                                                         Non-Null Count  Dtype
# ---  ------                                                                                                                                                         --------------  -----
#  0   Record ID                                                                                                                                                      702 non-null    float64
#  1   Institute                                                                                                                                                      702 non-null    object
# ...

# %%
tafe_survey.describe()
# Out:
#           Record ID  CESSATION YEAR
# count  7.020000e+02      695.000000
# mean   6.346026e+17     2011.423022
# std    2.515071e+14        0.905977
# min    6.341330e+17     2009.000000
# 25%    6.343954e+17     2011.000000
# 50%    6.345835e+17     2011.000000
# 75%    6.348005e+17     2012.000000
# max    6.350730e+17     2013.000000

# %%
pd.options.display.max_rows = 115
null_values = tafe_survey.isnull().sum()
null_values
# Out:
# Record ID                                                                                                                                                          0
# Institute                                                                                                                                                          0
# WorkArea                                                                                                                                                           0
# CESSATION YEAR                                                                                                                                                     7
# Reason for ceasing employment                                                                                                                                      1
# ...

# %%
tafe_survey['Reason for ceasing employment'].value_counts()
# Out:
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# Name: Reason for ceasing employment, dtype: int64

# %%
tafe_survey['Main Factor. Which of these was the main factor for leaving?'].value_counts()
# Out:
# Dissatisfaction with %[Institute]Q25LBL%    23
# Job Dissatisfaction                         22
# Other                                       18
# Career Move - Private Sector                16
# Interpersonal Conflict                       9
# Career Move - Public Sector                  8
# Maternity/Family                             6
# Career Move - Self-employment                4
# Ill Health                                   3
# Travel                                       2
# Study                                        2
# Name: Main Factor. Which of these was the main factor for leaving?, dtype: int64

# %% [markdown]
# ### TAFE Observations
# * The 'Main Factor' column is missing most of it's data, but it seems the values within the column are very similar to the 'Contributing Factors' columns.
# * Has a large amount of columns, I imagine we won't need most of them for the analysis

# %%
# Out:
# ID                                       0
# SeparationType                           0
# Cease Date                              34
# DETE Start Date                         73
# Role Start Date                         98
# Position                                 0
# Classification                           0
# Region                                 105
# Business Unit                            0
# Employment Status                        0
# Career move to public sector             0
# Career move to private sector            0
# Interpersonal conflicts                  0
# Job dissatisfaction                      0
# Dissatisfaction with the department      0
# Physical work environment                0
# Lack of recognition                      0
# Lack of job security                     0
# Work location                            0
# Employment conditions                    0
# Maternity/family                         0
# Relocation                               0
# ...

# %% [markdown]
# ## Cleaning

# %%
dete_survey = pd.read_csv('dete_survey.csv', na_values='Not Stated')

# %%
dete_survey[dete_survey == 'Not Stated'].count()
# Out:
# ID                                     0
# SeparationType                         0
# Cease Date                             0
# DETE Start Date                        0
# Role Start Date                        0
# Position                               0
# Classification                         0
# Region                                 0
# Business Unit                          0
# Employment Status                      0
# Career move to public sector           0
# Career move to private sector          0
# Interpersonal conflicts                0
# Job dissatisfaction                    0
# Dissatisfaction with the department    0
# Physical work environment              0
# Lack of recognition                    0
# Lack of job security                   0
# Work location                          0
# Employment conditions                  0
# Maternity/family                       0
# Relocation                             0
# Study/Travel                           0
# ...

# %%
dete_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   822 non-null    int64
#  1   SeparationType                       822 non-null    object
#  2   Cease Date                           788 non-null    object
#  3   DETE Start Date                      749 non-null    float64
#  4   Role Start Date                      724 non-null    float64
#  5   Position                             817 non-null    object
#  6   Classification                       455 non-null    object
#  7   Region                               717 non-null    object
#  8   Business Unit                        126 non-null    object
#  9   Employment Status                    817 non-null    object
#  10  Career move to public sector         822 non-null    bool
# ...

# %%
dete_survey_updated = dete_survey.drop(dete_survey.columns[28:49], axis=1)

# %%
dete_survey_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 35 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   822 non-null    int64
#  1   SeparationType                       822 non-null    object
#  2   Cease Date                           788 non-null    object
#  3   DETE Start Date                      749 non-null    float64
#  4   Role Start Date                      724 non-null    float64
#  5   Position                             817 non-null    object
#  6   Classification                       455 non-null    object
#  7   Region                               717 non-null    object
#  8   Business Unit                        126 non-null    object
#  9   Employment Status                    817 non-null    object
#  10  Career move to public sector         822 non-null    bool
# ...

# %%
tafe_survey_updated = tafe_survey.drop(tafe_survey.columns[17:66], axis=1)
tafe_survey_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 23 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   Record ID                                                                  702 non-null    float64
#  1   Institute                                                                  702 non-null    object
#  2   WorkArea                                                                   702 non-null    object
#  3   CESSATION YEAR                                                             695 non-null    float64
#  4   Reason for ceasing employment                                              701 non-null    object
#  5   Contributing Factors. Career Move - Public Sector                          437 non-null    object
# ...

# %% [markdown]
# As stated in earlier observations, I removed many columns that were either repetitive, missing to many values, or just not needed for the current analysis.

# %%
dete_survey_updated.columns
# Out:
# Index(['ID', 'SeparationType', 'Cease Date', 'DETE Start Date',
#        'Role Start Date', 'Position', 'Classification', 'Region',
#        'Business Unit', 'Employment Status', 'Career move to public sector',
#        'Career move to private sector', 'Interpersonal conflicts',
#        'Job dissatisfaction', 'Dissatisfaction with the department',
#        'Physical work environment', 'Lack of recognition',
#        'Lack of job security', 'Work location', 'Employment conditions',
#        'Maternity/family', 'Relocation', 'Study/Travel', 'Ill Health',
#        'Traumatic incident', 'Work life balance', 'Workload',
#        'None of the above', 'Gender', 'Age', 'Aboriginal', 'Torres Strait',
#        'South Sea', 'Disability', 'NESB'],
#       dtype='object')

# %%
tafe_survey_updated.columns
# Out:
# Index(['Record ID', 'Institute', 'WorkArea', 'CESSATION YEAR',
#        'Reason for ceasing employment',
#        'Contributing Factors. Career Move - Public Sector ',
#        'Contributing Factors. Career Move - Private Sector ',
#        'Contributing Factors. Career Move - Self-employment',
#        'Contributing Factors. Ill Health',
#        'Contributing Factors. Maternity/Family',
#        'Contributing Factors. Dissatisfaction',
#        'Contributing Factors. Job Dissatisfaction',
#        'Contributing Factors. Interpersonal Conflict',
#        'Contributing Factors. Study', 'Contributing Factors. Travel',
#        'Contributing Factors. Other', 'Contributing Factors. NONE',
#        'Gender. What is your Gender?', 'CurrentAge. Current Age',
#        'Employment Type. Employment Type', 'Classification. Classification',
#        'LengthofServiceOverall. Overall Length of Service at Institute (in years)',
# ...

# %%
dete_survey_updated.columns = dete_survey_updated.columns.str.lower().str.strip().str.replace(' ','_')

# %%
dete_survey_updated.columns
# Out:
# Index(['id', 'separationtype', 'cease_date', 'dete_start_date',
#        'role_start_date', 'position', 'classification', 'region',
#        'business_unit', 'employment_status', 'career_move_to_public_sector',
#        'career_move_to_private_sector', 'interpersonal_conflicts',
#        'job_dissatisfaction', 'dissatisfaction_with_the_department',
#        'physical_work_environment', 'lack_of_recognition',
#        'lack_of_job_security', 'work_location', 'employment_conditions',
#        'maternity/family', 'relocation', 'study/travel', 'ill_health',
#        'traumatic_incident', 'work_life_balance', 'workload',
#        'none_of_the_above', 'gender', 'age', 'aboriginal', 'torres_strait',
#        'south_sea', 'disability', 'nesb'],
#       dtype='object')

# %%
mapping = {
            'Record ID':'id',
            'CESSATION YEAR':'cease_date',
            'Reason for ceasing employment':'separationtype',
            'Gender. What is your Gender?':'gender',
            'CurrentAge. Current Age':'age',
            'Employment Type. Employment Type':'employment_status',
            'Classification. Classification':'position',
            'LengthofServiceOverall. Overall Length of Service at Institute (in years)':'institute_service',
            'LengthofServiceCurrent. Length of Service at current workplace (in years)':'role_service',
        }

tafe_survey_updated = tafe_survey_updated.rename(mapping, axis=1)

# %%
tafe_survey_updated.columns
# Out:
# Index(['id', 'Institute', 'WorkArea', 'cease_date', 'separationtype',
#        'Contributing Factors. Career Move - Public Sector ',
#        'Contributing Factors. Career Move - Private Sector ',
#        'Contributing Factors. Career Move - Self-employment',
#        'Contributing Factors. Ill Health',
#        'Contributing Factors. Maternity/Family',
#        'Contributing Factors. Dissatisfaction',
#        'Contributing Factors. Job Dissatisfaction',
#        'Contributing Factors. Interpersonal Conflict',
#        'Contributing Factors. Study', 'Contributing Factors. Travel',
#        'Contributing Factors. Other', 'Contributing Factors. NONE', 'gender',
#        'age', 'employment_status', 'position', 'institute_service',
#        'role_service'],
#       dtype='object')

# %%
dete_survey_updated.head()
# Out:
#    id                    separationtype cease_date  dete_start_date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
#
#    role_start_date                                      position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# 2           2011.0                               Schools Officer
# 3           2006.0                                       Teacher
# 4           1989.0  Head of Curriculum/Head of Special Education
#
#   classification              region                      business_unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %%
tafe_survey_updated.head()
# Out:
#              id                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date    separationtype  \
# 0  Non-Delivery (corporate)      2010.0  Contract Expired
# 1  Non-Delivery (corporate)      2010.0        Retirement
# 2       Delivery (teaching)      2010.0        Retirement
# 3  Non-Delivery (corporate)      2010.0       Resignation
# 4       Delivery (teaching)      2010.0       Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# 2                                                  -
# 3                                                  -
# ...

# %% [markdown]
# I plan on merging the two dataframes so I began to get the columns to match to see which ones we can pull together.

# %%
dete_survey_updated['separationtype'].value_counts()
# Out:
# Age Retirement                          285
# Resignation-Other reasons               150
# Resignation-Other employer               91
# Resignation-Move overseas/interstate     70
# Voluntary Early Retirement (VER)         67
# Ill Health Retirement                    61
# Other                                    49
# Contract Expired                         34
# Termination                              15
# Name: separationtype, dtype: int64

# %%
tafe_survey_updated['separationtype'].value_counts()
# Out:
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# Name: separationtype, dtype: int64

# %%
dete_survey_updated['separationtype'] = dete_survey_updated['separationtype'].str.split('-').str[0]

# %%
dete_survey_updated['separationtype'].value_counts()
# Out:
# Resignation                         311
# Age Retirement                      285
# Voluntary Early Retirement (VER)     67
# Ill Health Retirement                61
# Other                                49
# Contract Expired                     34
# Termination                          15
# Name: separationtype, dtype: int64

# %%
dete_resignations = dete_survey_updated[dete_survey_updated['separationtype'] == 'Resignation'].copy()

# %%
tafe_survey_updated['separationtype'].value_counts()
# Out:
# Resignation                 340
# Contract Expired            127
# Retrenchment/ Redundancy    104
# Retirement                   82
# Transfer                     25
# Termination                  23
# Name: separationtype, dtype: int64

# %%
tafe_resignations = tafe_survey_updated[tafe_survey_updated['separationtype'] == 'Resignation'].copy()

# %% [markdown]
# While trying to answer this question:
# * Are employees who only worked for insitutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been there longer?
# We are only paying attention to data of people who resigned.

# %%
dete_survey_updated.columns
# Out:
# Index(['id', 'separationtype', 'cease_date', 'dete_start_date',
#        'role_start_date', 'position', 'classification', 'region',
#        'business_unit', 'employment_status', 'career_move_to_public_sector',
#        'career_move_to_private_sector', 'interpersonal_conflicts',
#        'job_dissatisfaction', 'dissatisfaction_with_the_department',
#        'physical_work_environment', 'lack_of_recognition',
#        'lack_of_job_security', 'work_location', 'employment_conditions',
#        'maternity/family', 'relocation', 'study/travel', 'ill_health',
#        'traumatic_incident', 'work_life_balance', 'workload',
#        'none_of_the_above', 'gender', 'age', 'aboriginal', 'torres_strait',
#        'south_sea', 'disability', 'nesb'],
#       dtype='object')

# %%
dete_resignations['cease_date'].value_counts()
# Out:
# 2012       126
# 2013        74
# 01/2014     22
# 12/2013     17
# 06/2013     14
# 09/2013     11
# 11/2013      9
# 07/2013      9
# 10/2013      6
# 08/2013      4
# 05/2013      2
# 05/2012      2
# 09/2010      1
# 07/2012      1
# 07/2006      1
# 2010         1
# Name: cease_date, dtype: int64

# %%
dete_resignations['cease_date'].value_counts() # The column was accidentaly deleted, but I pulled only the years from the values, then converted to float.
# Out:
# 2013.0    146
# 2012.0    129
# 2014.0     22
# 2010.0      2
# 2006.0      1
# Name: cease_date, dtype: int64

# %%
dete_resignations['dete_start_date'].value_counts().sort_index()
# Out:
# 1963.0     1
# 1971.0     1
# 1972.0     1
# 1973.0     1
# 1974.0     2
# 1975.0     1
# 1976.0     2
# 1977.0     1
# 1980.0     5
# 1982.0     1
# 1983.0     2
# 1984.0     1
# 1985.0     3
# 1986.0     3
# 1987.0     1
# 1988.0     4
# 1989.0     4
# 1990.0     5
# 1991.0     4
# 1992.0     6
# 1993.0     5
# 1994.0     6
# 1995.0     4
# 1996.0     6
# 1997.0     5
# 1998.0     6
# 1999.0     8
# 2000.0     9
# 2001.0     3
# 2002.0     6
# 2003.0     6
# 2004.0    14
# 2005.0    15
# 2006.0    13
# 2007.0    21
# 2008.0    22
# 2009.0    13
# 2010.0    17
# 2011.0    24
# 2012.0    21
# 2013.0    10
# Name: dete_start_date, dtype: int64

# %%
tafe_resignations['cease_date'].value_counts().sort_index()
# Out:
# 2009.0      2
# 2010.0     68
# 2011.0    116
# 2012.0     94
# 2013.0     55
# Name: cease_date, dtype: int64

# %%
dete_resignations['cease_date'].value_counts().sort_index()
# Out:
# 2006.0      1
# 2010.0      2
# 2012.0    129
# 2013.0    146
# 2014.0     22
# Name: cease_date, dtype: int64

# %% [markdown]
# Between the two datasets, they have a few years that the others don't.

# %%
tafe_resignations['institute_service'].value_counts(dropna=False)
# Out:
# Less than 1 year      73
# 1-2                   64
# 3-4                   63
# NaN                   50
# 5-6                   33
# 11-20                 26
# 7-10                  21
# More than 20 years    10
# Name: institute_service, dtype: int64

# %%
dete_resignations[['cease_date','dete_start_date']]
# Out:
#      cease_date  dete_start_date
# 3        2012.0           2005.0
# 5        2012.0           1994.0
# 8        2012.0           2009.0
# 9        2012.0           1997.0
# 11       2012.0           2009.0
# 12       2012.0           1998.0
# 14       2012.0           2007.0
# 16       2012.0              NaN
# 20       2012.0           1982.0
# 21       2012.0           1980.0
# 22       2012.0           1997.0
# 23       2012.0           1973.0
# 25       2012.0           1995.0
# 27       2012.0           2005.0
# 33       2012.0           2003.0
# 34       2012.0           2006.0
# 37       2012.0           2011.0
# 39       2012.0              NaN
# 40       2012.0           1977.0
# 41       2012.0           1974.0
# 42       2012.0           2011.0
# 43       2012.0           1976.0
# 48       2012.0           2009.0
# 50       2012.0           2009.0
# 51       2012.0           1993.0
# 55       2012.0           2008.0
# 57       2012.0           2003.0
# ...

# %%
dete_resignations['institute_service'] = dete_resignations['cease_date'] - dete_resignations['dete_start_date']

# %%
dete_resignations['institute_service'].value_counts(dropna=False)
# Out:
# NaN     38
# 5.0     23
# 1.0     22
# 3.0     20
# 0.0     20
# 6.0     17
# 4.0     16
# 9.0     14
# 2.0     14
# 7.0     13
# 13.0     8
# 8.0      8
# 20.0     7
# 15.0     7
# 12.0     6
# 22.0     6
# 17.0     6
# 10.0     6
# 14.0     6
# 16.0     5
# 18.0     5
# 24.0     4
# 23.0     4
# 11.0     4
# 39.0     3
# 32.0     3
# 19.0     3
# 21.0     3
# 36.0     2
# 30.0     2
# 25.0     2
# 28.0     2
# 26.0     2
# 29.0     1
# 42.0     1
# 38.0     1
# 27.0     1
# 41.0     1
# 35.0     1
# 49.0     1
# 34.0     1
# 33.0     1
# 31.0     1
# Name: institute_service, dtype: int64

# %%
dete_resignations[['cease_date','dete_start_date']].count()
# Out:
# cease_date         300
# dete_start_date    283
# dtype: int64

# %% [markdown]
# We need to be able to determine years of service for both datasets, so one was added to the dete data set as well
# <br> The highest represented value in the new column is NaN, which is due to the missing start dates for some of the employees.

# %%
tafe_resignations['Contributing Factors. Dissatisfaction'].value_counts(dropna=False)
# Out:
# -                                         277
# Contributing Factors. Dissatisfaction      55
# NaN                                         8
# Name: Contributing Factors. Dissatisfaction, dtype: int64

# %%
tafe_resignations['Contributing Factors. Job Dissatisfaction'].value_counts(dropna=False)
# Out:
# -                      270
# Job Dissatisfaction     62
# NaN                      8
# Name: Contributing Factors. Job Dissatisfaction, dtype: int64

# %%
def update_vals(val):
    if pd.isnull(val):
        return np.nan
    elif val == '-':
        return False
    else:
        return True

# %%
tafe_resignations['dissatisfied'] = tafe_resignations[['Contributing Factors. Dissatisfaction','Contributing Factors. Job Dissatisfaction']].applymap(update_vals).any(axis=1, skipna=False)

# %%
tafe_resignations['dissatisfied'].value_counts(dropna=False)
# Out:
# False    241
# True      91
# NaN        8
# Name: dissatisfied, dtype: int64

# %%
tafe_resignations_up = tafe_resignations.copy()

# %%
tafe_resignations_up['dissatisfied'].value_counts(dropna=False)
# Out:
# False    241
# True      91
# NaN        8
# Name: dissatisfied, dtype: int64

# %%
dete_resignations.columns
# Out:
# Index(['id', 'separationtype', 'cease_date', 'dete_start_date',
#        'role_start_date', 'position', 'classification', 'region',
#        'business_unit', 'employment_status', 'career_move_to_public_sector',
#        'career_move_to_private_sector', 'interpersonal_conflicts',
#        'job_dissatisfaction', 'dissatisfaction_with_the_department',
#        'physical_work_environment', 'lack_of_recognition',
#        'lack_of_job_security', 'work_location', 'employment_conditions',
#        'maternity/family', 'relocation', 'study/travel', 'ill_health',
#        'traumatic_incident', 'work_life_balance', 'workload',
#        'none_of_the_above', 'gender', 'age', 'aboriginal', 'torres_strait',
#        'south_sea', 'disability', 'nesb', 'institute_service'],
#       dtype='object')

# %%
dete_resignations['dissatisfied'] = dete_resignations[[
                                                        'job_dissatisfaction',
                                                        'dissatisfaction_with_the_department',
                                                        'physical_work_environment',
                                                        'lack_of_recognition',
                                                        'lack_of_job_security',
                                                        'work_location',
                                                        'employment_conditions',
                                                        'work_life_balance',
                                                        'workload',
                                                    ]].any(axis=1, skipna=False)

# %%
dete_resignations['dissatisfied'].value_counts(dropna=False)
# Out:
# False    162
# True     149
# Name: dissatisfied, dtype: int64

# %%
dete_resignations_up = dete_resignations.copy()

# %% [markdown]
# we now pushed any columns we deemed as a type of 'dissatisfaction' all under one colomn that represents a True or False

# %%
dete_resignations_up['institute'] = 'DETE'
dete_resignations_up['institute'].value_counts()
# Out:
# DETE    311
# Name: institute, dtype: int64

# %%
tafe_resignations_up['institute'] = 'TAFE'
tafe_resignations_up['institute'].value_counts()
# Out:
# TAFE    340
# Name: institute, dtype: int64

# %%
combined = pd.concat([dete_resignations_up,tafe_resignations_up], ignore_index=True)

# %%
combined.notnull().sum()
# Out:
# id                                                     651
# separationtype                                         651
# cease_date                                             635
# dete_start_date                                        283
# role_start_date                                        271
# position                                               598
# classification                                         161
# region                                                 265
# business_unit                                           32
# employment_status                                      597
# career_move_to_public_sector                           311
# career_move_to_private_sector                          311
# interpersonal_conflicts                                311
# job_dissatisfaction                                    311
# dissatisfaction_with_the_department                    311
# physical_work_environment                              311
# ...

# %%
combined_up = combined.dropna(thresh=500,axis=1)

# %%
combined_up.notnull().sum()
# Out:
# id                   651
# separationtype       651
# cease_date           635
# position             598
# employment_status    597
# gender               592
# age                  596
# institute_service    563
# dissatisfied         643
# institute            651
# dtype: int64

# %%
combined_up.head()
# Out:
#      id separationtype  cease_date          position    employment_status  \
# 0   4.0    Resignation      2012.0           Teacher  Permanent Full-time
# 1   6.0    Resignation      2012.0  Guidance Officer  Permanent Full-time
# 2   9.0    Resignation      2012.0           Teacher  Permanent Full-time
# 3  10.0    Resignation      2012.0      Teacher Aide  Permanent Part-time
# 4  12.0    Resignation      2012.0           Teacher  Permanent Full-time
#
#    gender    age institute_service dissatisfied institute
# 0  Female  36-40                 7        False      DETE
# 1  Female  41-45                18         True      DETE
# 2  Female  31-35                 3        False      DETE
# 3  Female  46-50                15         True      DETE
# 4    Male  31-35                 3        False      DETE

# %%
combined_up.tail()
# Out:
#                id separationtype  cease_date                 position  \
# 646  6.350660e+17    Resignation      2013.0         Operational (OO)
# 647  6.350668e+17    Resignation      2013.0  Teacher (including LVT)
# 648  6.350677e+17    Resignation      2013.0                      NaN
# 649  6.350704e+17    Resignation      2013.0  Teacher (including LVT)
# 650  6.350730e+17    Resignation      2013.0      Administration (AO)
#
#        employment_status  gender     age institute_service dissatisfied  \
# 646  Temporary Full-time    Male  21  25               5-6        False
# 647  Temporary Full-time    Male   51-55               1-2        False
# 648                  NaN     NaN     NaN               NaN        False
# 649  Permanent Full-time  Female   51-55               5-6        False
# 650      Contract/casual  Female  26  30               3-4        False
#
#     institute
# 646      TAFE
# 647      TAFE
# 648      TAFE
# 649      TAFE
# 650      TAFE

# %% [markdown]
# We finally combined both datasets and removed any columns that have more than 500 empty values.

# %%
combined_up['institute_service'].value_counts(dropna=False)
# Out:
# NaN                   88
# Less than 1 year      73
# 1-2                   64
# 3-4                   63
# 5-6                   33
# 11-20                 26
# 5.0                   23
# 1.0                   22
# 7-10                  21
# 0.0                   20
# 3.0                   20
# 6.0                   17
# 4.0                   16
# 2.0                   14
# 9.0                   14
# 7.0                   13
# More than 20 years    10
# 8.0                    8
# 13.0                   8
# 15.0                   7
# 20.0                   7
# 14.0                   6
# 10.0                   6
# 12.0                   6
# 17.0                   6
# 22.0                   6
# 16.0                   5
# 18.0                   5
# 24.0                   4
# 11.0                   4
# 23.0                   4
# 19.0                   3
# 39.0                   3
# 21.0                   3
# 32.0                   3
# 25.0                   2
# 26.0                   2
# ...

# %%
combined_up['institute_service_up'] = combined_up['institute_service'].astype('str').str.extract(r'(\d+)')
# Out:
# <ipython-input-210-bee20f018021>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_up['institute_service_up'] = combined_up['institute_service'].astype('str').str.extract(r'(\d+)')

# %%
combined_up['institute_service_up'] = combined_up['institute_service_up'].astype('float')
combined_up['institute_service_up'].value_counts(dropna=False)
# Out:
# <ipython-input-213-98217733a316>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_up['institute_service_up'] = combined_up['institute_service_up'].astype('float')
# 1.0     159
# NaN      88
# 3.0      83
# 5.0      56
# 7.0      34
# 11.0     30
# 0.0      20
# 20.0     17
# 6.0      17
# 4.0      16
# 9.0      14
# 2.0      14
# 13.0      8
# 8.0       8
# 15.0      7
# 22.0      6
# 10.0      6
# 17.0      6
# 14.0      6
# 12.0      6
# 16.0      5
# 18.0      5
# 24.0      4
# 23.0      4
# 21.0      3
# 39.0      3
# 32.0      3
# 19.0      3
# 36.0      2
# 30.0      2
# 25.0      2
# 26.0      2
# 28.0      2
# 42.0      1
# 29.0      1
# 35.0      1
# 27.0      1
# 41.0      1
# 49.0      1
# 38.0      1
# 34.0      1
# ...

# %%
def match_cat(val):
    if val >= 11:
        return 'Veteran'
    elif val >= 7:
        return 'Established'
    elif val >= 3:
        return 'Experienced'
    elif val < 3:
        return 'New'
    elif pd.isnull(val):
        return np.nan

# %%
combined_up['service_cat'] = combined_up['institute_service_up'].apply(match_cat)

combined_up['service_cat'].value_counts(dropna=False)
# Out:
# <ipython-input-217-370685da35c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_up['service_cat'] = combined_up['institute_service_up'].apply(match_cat)
# New            193
# Experienced    172
# Veteran        136
# NaN             88
# Established     62
# Name: service_cat, dtype: int64

# %% [markdown]
# Instead of going off of ages, we will be analyzing based off of stages of a career within a company.

# %%
combined_up['dissatisfied'].value_counts(dropna=False)
# Out:
# False    403
# True     240
# NaN        8
# Name: dissatisfied, dtype: int64

# %%
combined_up['dissatisfied'] = combined_up['dissatisfied'].fillna(False)
# Out:
# <ipython-input-219-460f873beb92>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_up['dissatisfied'] = combined_up['dissatisfied'].fillna(False)

# %%
combined_up['dissatisfied'].value_counts(dropna=False)
# Out:
# False    411
# True     240
# Name: dissatisfied, dtype: int64

# %%
dis_ser = combined_up.pivot_table(index='service_cat', values='dissatisfied')

# %%
dis_ser
# Out:
#              dissatisfied
# service_cat
# Established      0.516129
# Experienced      0.343023
# New              0.295337
# Veteran          0.485294

# %%
# %matplotlib inline
dis_ser.plot(kind='bar', rot=30)

# %% [markdown]
# An initial analysis shows that employees who have been at the company the longest are the ones who resign for some dissatisfaction the most.
